# %% [markdown]
# # Taller 1 · Fundamentos de R: objetos, estructuras y selección
#
# **Clase 01 · Semana 11**
#
# Material de referencia: [01 · Fundamentos de R](../clases/01_fundamentos_R.ipynb).
#
# Practicarás tipos y clases, operaciones, vectores, ausentes, matrices, listas, factores, selección y conjuntos. Resuelve los ejercicios con las operaciones y funciones estudiadas en la clase 01; no se requieren estructuras de control ni definir funciones propias.
#
# ## Indicaciones
#
# Elige **Geología** o **Biología** y resuelve todos los ejercicios únicamente para ese contexto. Los datos son sintéticos y cada posición corresponde a la misma observación en todos los vectores.
#
# - Trabaja con R base; no necesitas archivos ni paquetes adicionales.
# - Conserva los datos originales y crea copias para añadir columnas o transformar valores.
# - Después de cada celda de código, añade una celda de texto que explique brevemente qué hace.
# - Presenta cada resultado final en una celda independiente e interpreta su significado y sus unidades. Añade las celdas que necesites.
# - Antes de entregar, reinicia el entorno y ejecuta las celdas en orden para comprobar que el notebook es reproducible.
#
# ## Entrega
#
# Sube el notebook a la carpeta de Teams con el nombre `2026_2-HC_ModuloR-Taller1-ApellidosNombres.ipynb`.
#
# **Plazo: sábado 26 de septiembre de 2026, a las 02:00 p. m.**  (martes 29, a las a las 02:00 p. m. para quien esté en campo el fin de semana)

# %% [markdown]
# ## Contexto: Geología
#
# Ocho muestras de una campaña sintética tienen los siguientes datos. Cada posición corresponde a la misma muestra en todos los vectores.
#
# | Variable | Valores |
# |---|---|
# | Identificador | G1, G2, G3, G4, G5, G6, G7, G8 |
# | Litología | arenisca, lutita, caliza, arenisca, caliza, lutita, arenisca, caliza |
# | Espesor (m) | 1.2, 0.8, NA, 2.1, 1.5, 0.6, 1.8, 0.9 |
# | Porosidad (%) | 8, 10, NA, 20, 25, 15, 5, 30 |
# | Densidad (g/cm³) | 2.60, 2.70, 2.90, 2.65, 2.75, NA, 2.55, 2.80 |
# | Fracturas (conteo) | 3, 9, 12, 5, 8, 10, 2, 11 |

# %% [markdown]
# ## Contexto: Biología
#
# Ocho parcelas de una campaña sintética tienen los siguientes datos. Cada posición corresponde a la misma parcela en todos los vectores.
#
# | Variable | Valores |
# |---|---|
# | Identificador | P1, P2, P3, P4, P5, P6, P7, P8 |
# | Hábitat | bosque, pastizal, bosque, humedal, pastizal, humedal, bosque, pastizal |
# | Área (m²) | 100, 200, 100, 150, 200, 150, 100, 200 |
# | Riqueza (especies) | 25, 12, 30, 20, 15, 22, 18, 10 |
# | Cobertura de dosel (%) | 85, 30, NA, 70, 40, 60, 20, 90 |
# | Abundancia (individuos) | 120, 60, 150, 100, 75, NA, 90, 40 |

# %% [markdown]
# ## 1. Construir e inspeccionar una tabla
#
# Crea un `data.frame` con los datos de tu contexto. Convierte litología o hábitat a factor. Consulta la estructura de la tabla y el tipo de una columna numérica; explica qué representa cada fila y por qué las columnas pueden tener tipos diferentes.

# %%
# Desarrollo del ejercicio 1

# %% [markdown]
# ## 2. Operaciones y precedencia
#
# Predice y comprueba, en celdas separadas, `5 + 2 * 3`, `(5 + 2) * 3`, `-3 ^ 2` y `(-3) ^ 2`. Explica el efecto de los paréntesis. Si debes distribuir 29 etiquetas entre grupos de 6, usa división entera y residuo para calcular cuántos grupos completos puedes formar y cuántas etiquetas sobran.

# %%
# Desarrollo del ejercicio 2

# %% [markdown]
# ## 3. Seleccionar y ordenar
#
# **Contexto: Geología:** selecciona muestras con más de 8 fracturas y densidad conocida mayor o igual que 2.7 g/cm³; ordénalas por densidad decreciente.
#
# **Contexto: Biología:** selecciona parcelas con riqueza mayor o igual que 20 y abundancia conocida mayor que 100; ordénalas por abundancia decreciente.
#
# Muestra identificador, categoría y variable de ordenamiento. Conserva la correspondencia entre columnas.

# %%
# Desarrollo del ejercicio 3

# %% [markdown]
# ## 4. Resumir valores con ausentes
#
# Trabaja con espesor en Geología o abundancia en Biología. Cuenta los valores ausentes y calcula la media de los conocidos. Explica por qué sustituir los ausentes por cero cambiaría la interpretación del promedio.

# %%
# Desarrollo del ejercicio 4

# %% [markdown]
# ## 5. Construir y operar una matriz
#
# Las mediciones sintéticas de tres sitios, con dos réplicas cada uno, son `c(4, 2, 0, 3, 5, 1)`. Construye una matriz 3 × 2 llenada por filas y asigna nombres a filas y columnas. Extrae la segunda fila conservando sus dimensiones. Multiplica la matriz por `c(0.5, 0.5)` usando `%*%` e interpreta el resultado como el promedio de las dos réplicas por sitio.
#
# > Nota: recuerda que `%*%` representa el producto (en este caso matriz-vector).  ¡Deberás consultar su definición matemática si no lo recuerdas!

# %%
# Desarrollo del ejercicio 5

# %% [markdown]
# ## 6. Organizar una lista
#
# Crea una lista `campana` que contenga el nombre de tu contexto, la tabla del ejercicio 1 y la matriz del ejercicio 5. Compara `campana["tabla"]` con `campana[["tabla"]]`. Explica la diferencia de estructura y extrae el primer identificador de la tabla guardada en la lista.

# %%
# Desarrollo del ejercicio 6

# %% [markdown]
# ## 7. Vectores, nombres y texto
#
# Extrae el vector de espesor (Geología) o abundancia (Biología) y asigna los identificadores como nombres con `names()`. Consulta su longitud, selecciona las observaciones primera y tercera por posición y luego por nombre, y excluye la segunda con un índice negativo.
#
# Construye etiquetas con `paste0()` que combinen identificador y litología o hábitat, separados por un guion. Usa `as.character()` para obtener las etiquetas del factor. Extrae con `substr()` la letra inicial de los identificadores y explica qué identifica en tu contexto.

# %%
# Desarrollo del ejercicio 7

# %% [markdown]
# ## 8. Tipos, conversiones y factores
#
# Consulta `class()`, `typeof()` y `mode()` de la columna litología o hábitat. Comprueba `is.factor()` e `is.numeric()` y explica por qué sus códigos internos no son mediciones.
#
# Crea un factor ordenado llamado `prioridad` a partir de `c("media", "alta", "baja", "media")`, con niveles `baja`, `media`, `alta`. Estas son etiquetas didácticas independientes de la tabla de ocho observaciones. Consulta sus niveles y compara `as.numeric(prioridad)` con `as.character(prioridad)`.
#
# Predice y comprueba el tipo de `c(2.6, "sin dato")`. Convierte `c("2.6", "2.8")` a números y explica la diferencia entre comprobar un tipo y convertirlo.

# %%
# Desarrollo del ejercicio 8

# %% [markdown]
# ## 9. Pertenencia y conjuntos
#
# Compara las categorías registradas en las primeras cuatro observaciones con las de las últimas cuatro. Extrae la litología o el hábitat como texto y crea los vectores `grupo_a` y `grupo_b`.
#
# Obtén las categorías presentes en cualquiera de los grupos, las compartidas y las exclusivas de cada grupo con `union()`, `intersect()` y `setdiff()`. Explica por qué las repeticiones desaparecen y por qué importa el orden de los argumentos de `setdiff()`.
#
# Usa `%in%` para seleccionar de la tabla original todas las observaciones cuya categoría aparezca en `grupo_b`. Muestra sus identificadores y categorías.

# %%
# Desarrollo del ejercicio 9

# %% [markdown]
# ## 10. Integrar selección y operaciones
#
# **Geología:** selecciona las muestras de arenisca o caliza con espesor conocido mayor o igual que 1 m. Crea en la tabla seleccionada una columna de espesor en centímetros.
#
# **Biología:** selecciona las parcelas de bosque o humedal con abundancia conocida mayor o igual que 100 individuos. Crea en la tabla seleccionada una columna de abundancia por unidad de área (individuos/m²).
#
# Construye la condición con operadores vectoriales y `is.na()`. Usa `which()` para mostrar las posiciones seleccionadas en la tabla original. Ordena la tabla seleccionada de mayor a menor según la nueva variable y muestra identificador, categoría y valor calculado. Escribe dos conclusiones respaldadas por tus resultados.

# %%
# Desarrollo del ejercicio 10

# %% [markdown]
# ## Revisión de la entrega
#
# Incluye los diez ejercicios del contexto elegido, conserva los enunciados y completa las explicaciones. Comprueba que los filtros no generen filas de valores ausentes y que las unidades estén indicadas.
